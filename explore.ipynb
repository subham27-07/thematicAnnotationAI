# %%
import pandas as pd 
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

# %%
df=pd.read_csv('Qual Analysis - accounts_tidy.csv')

# %%
df.head(2)
# Out:
#                                 user_id condition user_finish_id  account  \
# 0  e5188116-f79c-476a-b681-859c8c386e61        ai         67fb6d        1
# 1  e5188116-f79c-476a-b681-859c8c386e61        ai         67fb6d        2
#
#    accountsOrder                                      justification   aor  \
# 0          13452  The person is advocating hate speech and viole...  1.00
# 1          13452    Another account advocating actual IRL violence.  0.75
#
#    num_messages account_suspension  account_confidence  account_duration
# 0             2            Suspend                 5.0             3.306
# 1             1            Suspend                 5.0             3.887

# %%
df1=df[251:]

# %%
df1.head(2)
# Out:
#                                   user_id condition user_finish_id  account  \
# 251  a69e967a-c238-4245-8091-e518ed2326f6   control         b23175        2
# 252  a69e967a-c238-4245-8091-e518ed2326f6   control         b23175        3
#
#      accountsOrder                                      justification   aor  \
# 251          43512  More inflammatory remarks about someone's orie...  0.75
# 252          43512  Any sort of derogatory slurs let's me know tha...  0.50
#
#      num_messages account_suspension  account_confidence  account_duration
# 251             4            Suspend                3.76            10.693
# 252             1            Suspend                5.00            20.891

# %%
len(df1)
# Out:
# 1199

# %%
len(df)
# Out:
# 1450
